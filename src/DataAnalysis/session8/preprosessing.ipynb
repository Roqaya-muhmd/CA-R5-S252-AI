# %%
import sys

print(sys.executable)

import pandas as pd
import numpy as np

print("SUCCESS")
# Out:
# c:\Users\hp\python.exe
# SUCCESS

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Titanic.csv')

# %%
# dropped_cols = ['Name', 'PassengerId', 'Ticket']
from config import dropped_cols

# %%
def drop_columns(df: pd.DataFrame, dropped_cols: list[str]) -> pd.DataFrame:
    df = df.drop(dropped_cols, axis=1)
    return df

# %%
dropped_df = drop_columns(df, dropped_cols)

# %%
cat_cols= ["Survived", "Pclass", "Sex", "SibSp","Parch", "Embarked"]
df[cat_cols] = df[cat_cols].astype("category")

df
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
df.dtypes
nunique_values = df.nunique()
pd.DataFrame({'dtypes': df.dtypes, 'nunique': nunique_values})
# Out:
#                dtypes  nunique
# PassengerId     int64      891
# Survived     category        2
# Pclass       category        3
# Name           object      891
# Sex          category        2
# Age           float64       88
# SibSp        category        7
# Parch        category        7
# Ticket         object      681
# Fare          float64      248
# Cabin          object      147
# Embarked     category        3

# %%
df.select_dtypes(include=['category'])
# Out:
#     Survived Pclass     Sex SibSp Parch Embarked
# 0          0      3    male     1     0        S
# 1          1      1  female     1     0        C
# 2          1      3  female     0     0        S
# 3          1      1  female     1     0        S
# 4          0      3    male     0     0        S
# ..       ...    ...     ...   ...   ...      ...
# 886        0      2    male     0     0        S
# 887        1      1  female     0     0        S
# 888        0      3  female     1     2        S
# 889        1      1    male     0     0        C
# 890        0      3    male     0     0        Q
#
# [891 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
null = df.isnull().sum()
ratio = (null/ 891)*100
ratio
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df=df.dropna(subset=['Embarked'])
df
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
df=df.drop(columns=['Cabin'],axis=1)

# %%
df
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
df.describe(include='all')
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex  \
# count    889.000000     889.0   889.0                      889   889
# unique          NaN       2.0     3.0                      889     2
# top             NaN       0.0     3.0  Braund, Mr. Owen Harris  male
# freq            NaN     549.0   491.0                        1   577
# mean     446.000000       NaN     NaN                      NaN   NaN
# std      256.998173       NaN     NaN                      NaN   NaN
# min        1.000000       NaN     NaN                      NaN   NaN
# 25%      224.000000       NaN     NaN                      NaN   NaN
# 50%      446.000000       NaN     NaN                      NaN   NaN
# 75%      668.000000       NaN     NaN                      NaN   NaN
# max      891.000000       NaN     NaN                      NaN   NaN
#
#                Age  SibSp  Parch  Ticket        Fare Embarked
# count   712.000000  889.0  889.0     889  889.000000      889
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    category
#  2   Pclass       889 non-null    category
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    category
#  5   Age          712 non-null    float64
#  6   SibSp        889 non-null    category
#  7   Parch        889 non-null    category
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    category
# dtypes: category(6), float64(2), int64(1), object(2)
# memory usage: 48.1+ KB

# %%
num_cols=df.select_dtypes('number').columns
for col in num_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75) 
    qr = q3 - q1
    lower_bound = q1 - 1.5 * qr
    upper_bound = q3 + 1.5 * qr
    df[col] = np.where((df[col] < lower_bound) | (df[col] > upper_bound), np.nan, df[col])

# %%
def remove_duplicates(df, subset_col = None, keep_strategy = "first"):
    return (df.drop_duplicates(subset = subset_col, keep=keep_strategy).reset_index(drop = True))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ["Survived","Pclass","Sex","SibSp","Parch","Embarked"]
df[cols] =df[cols].astype("category")

# %%
cat_cols = df.select_dtypes("category").columns
plt.figure(figsize=(10,8))
for i , col in enumerate(cat_cols):
 plt.subplot(3, 3, i+1)
 sns.countplot (x = col, data = df)
 plt.title(f" {col} count plot")
 plt.subplots_adjust(hspace=0.8, wspace=0.3)
 plt.show()

# %%
print(cat_cols)
unique = df['Survived' ].value_counts ()
counts = unique. values
counts

# %%
print(cat_cols)
unique = df['Survived'].value_counts ()
counts = unique. values
categories = unique.index
categories
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')
# CategoricalIndex([0, 1], categories=[0, 1], ordered=False, dtype='category', name='Survived')

# %%
plt.figure(figsize=(9, 4))
for i, col in enumerate(cat_cols):
	plt.subplot(2, 3, i + 1)
	unique = df[col].value_counts()
	counts = unique.values
	categories = unique.index
	plt.pie(counts, labels=categories, autopct='%1.1f%%')
	plt.title(f"{col} pie plot")
	plt.subplots_adjust(hspace=0.8, wspace=0.3)
plt.show()

# %%
plt.figure(figsize=(9,4))
for i ,col in enumerate(cat_cols):
 plt.subplot(2,3,i+1)
 unique = df['Survived']. value_counts ()
 counts = unique.values
 categories = unique.index
