# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.5 MB 728.2 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.5 MB 780.2 kB/s eta 0:00:15
#    --- ------------------------------------ 1.0/12.5 MB 914.5 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.5 MB 958.5 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.5 MB 958.5 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.5 MB 902.1 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.8/12.5 MB 906.5 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.5 MB 906.5 kB/s eta 0:00:12
# ...

# %%
import numpy as np

# %%
v=np.array([1, 2, 3])
print(v.ndim)
# Out:
# 1
