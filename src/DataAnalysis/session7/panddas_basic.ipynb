# %%
import numpy as np

# %%
arr=np.array([3,1,2])
arr.shape
# Out:
# (3,)

# %%
mat1=np.ones((3,4))
mat2=np.zeros((3,4))

# %%
np.savez('file_.npz',mat_one=mat1,mat_zero=mat2)

# %%
with np.load('file_.npz') as file:
    mat1=file['mat_one']
    mat2=file['mat_zero']

# %%
m1 = np.array([[1,2,3],
[0,0,0]])
m2 = np.array([[4,5,6],
[1,1,1]])
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
new_mat = np.hstack((m1, m2))
new_mat
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [0, 0, 0, 1, 1, 1]])

# %%
new_mat = np.vstack((m1, m2))
new_mat
# Out:
# array([[1, 2, 3],
#        [0, 0, 0],
#        [4, 5, 6],
#        [1, 1, 1]])

# %%
v1 = np.array([1,2,3,4,5])
v2 = np.array([2,3,0,5,3])
np.isclose(v1,v2, atol= 2)
# Out:
# array([ True,  True,  True,  True,  True])

# %%
np.allclose(v1,v2, atol= 3)
# Out:
# True

# %%
V = np.array ([2,4,3,4,10])
condition = V>=4
print(condition)
# Out:
# [False  True False  True  True]

# %%
V[condition]=-1
print(V)
print(type(V))
# Out:
# [ 2 -1  3 -1 -1]
# <class 'numpy.ndarray'>

# %%
new_arr=np.where(condition,-1,V)
print(new_arr)
# Out:
# [ 2 -1  3 -1 -1]
