# %%
x=5
print(x)
# Out:
# 5

# %%
name = "ٌRoqaya muhammad"
age = 20
course_name = "ML"
output = f"my name is {name} my age is {age} and the name of the course is {course_name}"
print (output)
# Out:
# my name is ٌRoqaya muhammad my age is 20 and the name of the course is ML
