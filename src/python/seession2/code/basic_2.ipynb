# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
list_1 = [1,2,3,4,"Depi", "learning",True,[1,2,3,["ML", "AI","GenAI"]]]

# %%
list_1=["Depi", "learning","ML"]
list_1.append("AI")
list_1
# Out:
# ['Depi', 'learning', 'ML', 'AI']

# %%
list_1=["Depi", "learning","ML"]
list_1.insert(2,"AI")
list_1
# Out:
# ['Depi', 'learning', 'AI', 'ML']

# %%
list_1=["Depi", "learning","ML"]
list_2=["NTI", "learning","AI"]
list_1.extend(list_2)

# %%
list_1=["Depi", "learning","ML","learning"]
list_1.remove("learning")
list_1
# Out:
# ['Depi', 'ML', 'learning']

# %%
list_1=["Depi", "learning","ML",1]

print(type(list_1.pop()))
# Out:
# <class 'int'>

# %%
del list_1[0]
list_1
# Out:
# ['learning', 'ML']

# %%
del list_1

# %%
list_1=["Depi", "learning","ML"]
item=input("Enter the item to be searched: ")
list_1.remove(item)
list_1
# Out:
# ['Depi', 'learning']

# %%
tup=("Depi", "learning","ML")
item=input("Enter the item to be searched: ")
l=list(tup)
l.remove(item)
tuple(l)
# Out:
# ('Depi', 'learning')

# %%
s1={1,2,3}
s2={3,4,5}
print(s1|s2)
print(s1&s2)
print(s1-s2)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %%
dict_1={"name":"Depi", "age":20, "course":"AI"}

# %%
key_value_list=[("name","Depi"), ("age",20), ("course","AI")]
dic_from_list=dict(key_value_list)
dic_from_list
# Out:
# {'name': 'Depi', 'age': 20, 'course': 'AI'}

# %%
n1=int(input("Enter  number "))
n2=int(input("Enter  number "))
print("The sum of two numbers is: ", n1+n2)
print("The difference of two numbers is: ", n1-n2)
print("The product of two numbers is: ", n1*n2)
print("The quotient of two numbers is: ", n1/n2)
# Out:
# The sum of two numbers is:  5
# The difference of two numbers is:  -1
# The product of two numbers is:  6
# The quotient of two numbers is:  0.6666666666666666

# %%
grade=int(input("Enter your grade: "))
print("A")if grade>=90 else( print("B") if grade>=80 else (print("C") if grade>=70 else( print("D") if grade>=60 else print("F"))))
# Out:
# C
