# %%
def user_info(name, age=20):
    """
    brief description of your function

    Args:
        param_name(str): this is string input for name o
        param_age(int): this is int input fot the user a

    Returns:
        return_type: print the description for user info
    Examples:
        >>> function.
    """
    print(f"my name is {name}, my age is {age}")

# %%
user_info("John")
# Out:
# my name is John, my age is 20

# %%
def func3( ** name):
    print(name)
    print(type(name))

# %%
func3(k1 = 10, k2 =20.5, k3 = "machine learning")
# Out:
# {'k1': 10, 'k2': 20.5, 'k3': 'machine learning'}
# <class 'dict'>

# %%
def training_model(model_name, *datasets, **hyperparameters):
    print(f"Training model: {model_name}")
    print(f"Datasets: {datasets}")
    for dataset in datasets:
        print(f"Dataset: {dataset}")
    print(f"Hyperparameters: {hyperparameters}")
    for key, value in hyperparameters.items():
        print(f"key{key}: value{value}")

# %%
training_model("RandomForest", "dataset1.csv", "dataset2.csv", n_estimators=100, max_depth=10, random_state=42)
# Out:
# Training model: RandomForest
# Datasets: ('RandomForest', 'dataset1.csv', 'dataset2.csv')
# Dataset: RandomForest
# Dataset: dataset1.csv
# Dataset: dataset2.csv
# Hyperparameters: {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}
# keyn_estimators: value100
# keymax_depth: value10
# keyrandom_state: value42
